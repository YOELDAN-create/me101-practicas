# %%
import pandas as pd
import numpy as np

print("El entorno está funcionando")
print("pandas:", pd.__version__, "numpy:", np.__version__)
# Out:
# El entorno está funcionando
# pandas: 3.0.5 numpy: 2.5.2
