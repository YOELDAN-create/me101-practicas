# %%
import numpy as np

notas = np.array([11, 14, 20, 8, 16, 13])

print("Shape:", notas.shape)
print("Dtype:", notas.dtype)
print("Ndim:", notas.ndim)
# Out:
# Shape: (6,)
# Dtype: int64
# Ndim: 1

# %%
promedio = notas.mean()
maximo = notas.max()
cantidad_aprobados = (notas >= 13.5).sum()

print("Promedio:", promedio)
print("Maximo:", maximo)
print("Aprobados:", cantidad_aprobados)
# Out:
# Promedio: 13.666666666666666
# Maximo: 20
# Aprobados: 3

# %%
import pandas as pd

datos = {
    "nombre": ["Yoel", "Ana", "Carlos", "Maria", "Luis"],
    "nota": [15, 9, 18, 12, 8],
    "asistencia_pct": [19, 16, 18, 14, 17]
}

df = pd.DataFrame(datos)

print(df)
# Out:
#    nombre  nota  asistencia_pct
# 0    Yoel    15              19
# 1     Ana     9              16
# 2  Carlos    18              18
# 3   Maria    12              14
# 4    Luis     8              17
